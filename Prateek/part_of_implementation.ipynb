# %%
import nltk
import string
import re
import numpy as np
import pandas as pd
import pickle
#import lda

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white")

from nltk.stem.porter import *
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction import stop_words

from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation


# %matplotlib inline


import warnings
warnings.filterwarnings('ignore')
import logging
logging.getLogger("lda").setLevel(logging.WARNING)

# %%
PATH="/home/prateek/Price-Prediction-from-ItemDescription-using-LDA/Prateek/mercari-price-suggestion-challenge/"

train=pd.read_csv(f'{PATH}train.tsv',sep='\t')
test = pd.read_csv(f'{PATH}test.tsv', sep='\t')

# %%
print(train.shape)
print(test.shape)
# Out:
# (1482535, 8)
# (693359, 7)

# %%
train.dtypes
# Out:
# train_id               int64
# name                  object
# item_condition_id      int64
# category_name         object
# brand_name            object
# price                float64
# shipping               int64
# item_description      object
# dtype: object

# %%
train.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity

# %%
stop=set(stopwords.words('english'))
def tokenize(text):
    try:
        regex=re.compile("["+string.punctuation+"0-9\\r\\t\\n]")
        text=regex.sub(" ",text)
        
        tokens_=[word_tokenize(s) for s in sent_tokenize(text)]
        tokens=[]
        for token_by_sent in tokens_:
            tokens+=token_by_sent;
        
        tokens=list(filter(lambda t:t.lower() not in stop,tokens))
        filtered_tokens=[w for w in tokens if re.search('[a-zA-Z]',w)]
        filtered_tokens = [w.lower() for w in filtered_tokens if len(w)>=3]
        
        return filtered_tokens
    
    except TypeError as e :print(text,e)

# %%
train['tokens']=train['item_description'].head().map(tokenize)
test["tokens"]=test["item_description"].head().map(tokenize)

# %%
train.reset_index(drop=True,inplace=True)
test.reset_index(drop=True,inplace=True)

# %%
for description,tokens in zip(train["item_description"].head(),train["tokens"].head()):
    print("description:",description)
    print("tokens:",tokens)
    print()
# Out:
# description: No description yet
# tokens: ['description', 'yet']
#
# description: This keyboard is in great condition and works like it came out of the box. All of the ports are tested and work perfectly. The lights are customizable via the Razer Synapse app on your PC.
# tokens: ['keyboard', 'great', 'condition', 'works', 'like', 'came', 'box', 'ports', 'tested', 'work', 'perfectly', 'lights', 'customizable', 'via', 'razer', 'synapse', 'app']
#
# description: Adorable top with a hint of lace and a key hole in the back! The pale pink is a 1X, and I also have a 3X available in white!
# tokens: ['adorable', 'top', 'hint', 'lace', 'key', 'hole', 'back', 'pale', 'pink', 'also', 'available', 'white']
#
# description: New with tags. Leather horses. Retail for [rm] each. Stand about a foot high. They are being sold as a pair. Any questions please ask. Free shipping. Just got out of storage
# tokens: ['new', 'tags', 'leather', 'horses', 'retail', 'stand', 'foot', 'high', 'sold', 'pair', 'questions', 'please', 'ask', 'free', 'shipping', 'got', 'storage']
#
# description: Complete with certificate of authenticity
# tokens: ['complete', 'certificate', 'authenticity']

# %%
print("There are %d unique values in the category column." % train['category_name'].nunique())
# Out:
# There are 1287 unique values in the category column.

# %%
train["category_name"].value_counts()[:5]
# Out:
# Women/Athletic Apparel/Pants, Tights, Leggings    60177
# Women/Tops & Blouses/T-Shirts                     46380
# Beauty/Makeup/Face                                34335
# Beauty/Makeup/Lips                                29910
# Electronics/Video Games & Consoles/Games          26557
# Name: category_name, dtype: int64

# %%
print("There are %d items that do not have a label." % train['category_name'].isnull().sum())
# Out:
# There are 6327 items that do not have a label.

# %%
def split_cat(text):
    try: return text.split("/")
    except: return ("No Label", "No Label", "No Label")

# %%
train['general_cat'], train['subcat_1'], train['subcat_2'] = zip(*train['category_name'].apply(lambda x: split_cat(x)))
train.head()
# Out:
#          train_id                                   name  item_condition_id  \
# 1482495   1482495                            XBOX Bundle                  3
# 1482496   1482496           Benefit they're real mascara                  1
# 1482497   1482497         Wet Seal Pink Bodysuit size XL                  2
# 1482498   1482498      Cupquake beauty rush mist ON HOLD                  3
# 1482499   1482499                              iPhone 7+                  2
# 1482500   1482500               Brandy Melville crop top                  2
# 1482501   1482501    Jeffrey Star Velour Liquid Lipstick                  2
# 1482502   1482502         MURANO, GLASS FISH PAPERWEIGHT                  3
# 1482503   1482503                                Bundle!                  2
# 1482504   1482504                        Herschel Wallet                  1
# 1482505   1482505                 NorthFace rain jacket!                  3
# 1482506   1482506             KitchenAid 4.5 quart mixer                  1
# 1482507   1482507           Grand Theft Auto V: XBOX ONE                  3
# 1482508   1482508              Victoria secret black bag                  1
# 1482509   1482509                        Fitbit Charge 2                  3
# 1482510   1482510    2×Popsockets for all phone & Tablet                  1
# 1482511   1482511       Bebe Beauty Gloss Icon Lip Gloss                  1
# 1482512   1482512                              Lululemon                  2
# 1482513   1482513      Yugioh Ultra Rare B. Skull Dragon                  3
# 1482514   1482514                   Anthropologie Purse!                  3
# 1482515   1482515                    Pink Yankees hoodie                  3
# 1482516   1482516   New Bath & Body Works Scented Candle                  1
# 1482517   1482517            34D VS PINK red push up bra                  3
# 1482518   1482518   Brooches: lot of 5 assorted (1 Coro)                  3
# 1482519   1482519           SALE! FreeShip VS Logo Thong                  1
# 1482520   1482520                       Bundle for BeSpa                  3
# 1482521   1482521     Tarte Amazonian clay 12 hour blush                  1
# 1482522   1482522            LG K7/Tribute 5 Hybrid Case                  1
# 1482523   1482523                NARS illuminator orgasm                  3
# 1482524   1482524           Penn State Jogger Sweatpants                  2
# 1482525   1482525    Red Victoria's Secret bra w sequins                  2
# 1482526   1482526   Harry Potter Shirt! Women M/ Girl XL                  2
# 1482527   1482527  Blk/white ribbed mock neck bodysuit M                  1
# 1482528   1482528    Victoria's Secret Tankini Sz. Large                  2
# 1482529   1482529                          Men's UA [rm]                  2
# 1482530   1482530             Free People Inspired Dress                  2
# 1482531   1482531          Little mermaid handmade dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                                              category_name  \
# 1482495           Electronics/Video Games & Consoles/Games
# 1482496                                 Beauty/Makeup/Eyes
# 1482497                        Women/Tops & Blouses/Blouse
# 1482498                             Beauty/Fragrance/Women
# 1482499  Electronics/Cell Phones & Accessories/Cell Pho...
# 1482500                    Women/Tops & Blouses/Tank, Cami
# 1482501                                 Beauty/Makeup/Lips
# 1482502                 Home/Home Décor/Home Décor Accents
# 1482503                           Women/Jeans/Slim, Skinny
# 1482504                      Men/Men's Accessories/Wallets
# 1482505                     Women/Coats & Jackets/Raincoat
# 1482506            Home/Home Appliances/Kitchen Appliances
# 1482507           Electronics/Video Games & Consoles/Games
# 1482501  Hey so I ordered these online and finally got ...    NaN
# 1482502  Made In Italy, Solid Glass and Very Heavy, Pap...    NaN
# 1482503  Brett fit, in great condition. and I will bund...    NaN
# 1482504  Bi-fold wallet from Herschel Supply Co. Premiu...    NaN
# 1482505  great condition! a few signs of wear on the in...    NaN
# 1482506  Brand new sealed in box kitchen aid kitchenaid...    NaN
# 1482507          Just the game and the case. Lightly used.    NaN
# 1482508                                      New with tags    NaN
# 1482509  Fit bit charge 2, comes with box, charger pack...    NaN
# 1482510  Popsockets for all phone & Tablet Add 1 clip m...    NaN
# 1482511  Brand: Bebe Beauty lip gloss, in color Icon. B...    NaN
# 1482512                               NWOT - Blue - size 8    NaN
# 1482513  Yu-Gi-Oh Ultra Rare Single Card in NM conditio...    NaN
# 1482514  Leather Navy and creme polka dot With brown ac...    NaN
# 1482515                                        Size medium    NaN
# 1482516  Bath & Body Works Scented Candle Vanilla Bloss...    NaN
# 1482517  To see all of the bras I have listed key in JB...    NaN
# 1482518          3 appear to be VTG. The pink one is Coro.    NaN
# 1482519  Brand new with tags, Victoria Secret logo thon...    NaN
# 1482520  Bundle of Baby Gap's First Favorites 3-6 month...    NaN
# 1482521                             Brand new, never used.    NaN
# 1482522  Perfect Design for LG Tribute 5 / LG K7, NOT f...    NaN
# 1482523  Still more than half left in this! Color is or...    NaN
# 1482524  ▪️NWOT ▪️Perfect Condition ▪️Barely been worn ...    NaN
# 1482525  Removable straps to make strapless Size: 34 B ...    NaN
# 1482526  Great Harry Potter Shirt! "Hogwarts, School of...    NaN
# 1482527  Brand new black and white ribbed mock neck bod...    NaN
# 1482528  Purple and Paisley Victoria's Secret Tankini S...    NaN
# 1482529  [rm] for the set both in perfect condition no ...    NaN
# 1482530  Lace, says size small but fits medium perfectl...    NaN
# 1482531   Little mermaid handmade dress never worn size 2t    NaN
# 1482532          Used once or twice, still in great shape.    NaN
# 1482533  There is 2 of each one that you see! So 2 red ...    NaN
# 1482534  New with tag, red with sparkle. Firm price, no...    NaN
#
#                     general_cat                   subcat_1  \
# 1482495             Electronics     Video Games & Consoles
# 1482496                  Beauty                     Makeup
# 1482497                   Women             Tops & Blouses
# 1482498                  Beauty                  Fragrance
# 1482499             Electronics  Cell Phones & Accessories
# 1482500                   Women             Tops & Blouses
# 1482501                  Beauty                     Makeup
# 1482502                    Home                 Home Décor
# 1482503                   Women                      Jeans
# 1482504                     Men          Men's Accessories
# 1482505                   Women            Coats & Jackets
# 1482506                    Home            Home Appliances
# 1482507             Electronics     Video Games & Consoles
# 1482508                   Women           Women's Handbags
# 1482509       Sports & Outdoors                   Exercise
# 1482510             Electronics  Cell Phones & Accessories
# 1482511                  Beauty                     Makeup
# 1482512                   Women           Athletic Apparel
# 1482513  Vintage & Collectibles              Trading Cards
# 1482514                Handmade            Bags and Purses
# 1482515                   Women                   Sweaters
# 1482516                    Home                 Home Décor
# 1482517                   Women                  Underwear
# 1482518  Vintage & Collectibles                    Jewelry
# 1482519                   Women                  Underwear
# 1482520                    Kids              Boys 0-24 Mos
# 1482521                  Beauty                     Makeup
# 1482522             Electronics  Cell Phones & Accessories
# 1482523                  Beauty                     Makeup
# 1482524                   Women           Athletic Apparel
# 1482525                   Women                  Underwear
# 1482526                   Women             Tops & Blouses
# 1482527                   Women             Tops & Blouses
# 1482528                   Women           Athletic Apparel
# 1482529                     Men           Athletic Apparel
# 1482530                   Women                    Dresses
# 1482531                    Kids                Girls 2T-5T
# 1482532       Sports & Outdoors                   Exercise
# 1482533                    Home                 Home Décor
# 1482534                   Women        Women's Accessories
#
#                           subcat_2
# 1482495                      Games
# 1482496                       Eyes
# 1482497                     Blouse
# 1482498                      Women
# 1482499  Cell Phones & Smartphones
# 1482500                 Tank, Cami
# 1482501                       Lips
# 1482502         Home Décor Accents
# 1482503               Slim, Skinny
# 1482504                    Wallets
# 1482505                   Raincoat
# 1482506         Kitchen Appliances
# 1482507                      Games
# 1482508               Shoulder Bag
# 1482509        Fitness accessories
# 1482510     Cell Phone Accessories
# 1482511                       Lips
# 1482512              Shirts & Tops
# 1482513                  Animation
# 1482514                      Purse
# 1482515                     Hooded
# 1482516          Candles & Holders
# 1482517                       Bras
# 1482518                     Brooch
# 1482519                    Panties
# 1482520                 One-Pieces
# 1482521                       Face
# 1482522      Cases, Covers & Skins
# 1482523                       Face
# 1482524        Tracksuits & Sweats
# 1482525                       Bras
# 1482526                   T-Shirts
# 1482527                     Blouse
# 1482528                Sports Bras
# 1482529              Shirts & Tops
# 1482530                   Mid-Calf
# 1482531                    Dresses
# 1482532        Fitness accessories
# 1482533         Home Décor Accents
# 1482534                    Wallets

# %%
general_cats = train['general_cat'].unique()
print(general_cats)
# Out:
# ['Men' 'Electronics' 'Women' 'Home' 'Sports & Outdoors'
#  'Vintage & Collectibles' 'Beauty' 'Other' 'Kids' 'No Label' 'Handmade']

# %%
cat_desc=dict()
#before running uncomment loop for all general_cats
# for cat in general_cats:
text=" ".join(train.loc[train["general_cat"]=="Men","item_description"].values)
cat_desc["Men"]=tokenize(text)

# %%
print(cat_desc["Men"][0:100])
# Out:
# ['description', 'yet', 'percent', 'authentic', 'beaters', 'still', 'lot', 'life', 'original', 'box', 'wear', 'back', 'white', 'spots', 'believe', 'washed', 'men', 'xxl', 'good', 'condition', 'minor', 'mark', 'sleeve', 'worn', 'washed', 'sent', 'rose', 'gold', 'bezel', 'crown', 'engraved', 'logo', 'red', 'green', 'signature', 'band', 'unisex', 'box', 'boys', 'lebron', 'soldier', 'great', 'condition', 'black', 'ferragamo', 'belt', 'fit', 'sizes', 'nothing', 'loose', 'order', 'item', 'described', 'simply', 'return', 'package', 'get', 'money', 'back', 'brand', 'new', 'packaging', 'never', 'worn', 'guaranteed', 'authentic', 'bought', 'nordstrom', 'women', 'never', 'worn', 'comes', 'receipt', 'sleep', 'fresh', 'men', 'nike', 'dri', 'fit', 'shirt', 'blue', 'items', 'come', 'clean', 'smoke', 'pet', 'free', 'home', 'flash', 'sale', 'today', 'sunday', 'like', 'new', 'purchased', 'last', 'may', 'worn', 'times', 'retail']
